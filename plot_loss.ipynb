# %%
import os 
import matplotlib.pyplot as plt
import pandas as pd

# %%
fp = 'output/train/stf_1280_weights/rgb1280/summary.csv'
df = pd.read_csv(fp)

# %%
plt.plot(df['eval_loss'], label='val')
plt.plot(df['train_loss'], label='train')
plt.legend()
plt.show()
